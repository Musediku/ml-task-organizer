# %%
import joblib
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LinearRegression

# %%
full_pipeline = joblib.load("feature_pipeline_unfitted.pkl")

X = df.drop(columns=["completion_time"])
y = df["completion_time"]

model_pipeline = Pipeline([
    ("features", full_pipeline),
    ("regressor", LinearRegression())
])

scores = cross_val_score(model_pipeline, X, y, cv=5, scoring="neg_mean_squared_error")
print(-scores)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 full_pipeline = joblib.load("feature_pipeline_unfitted.pkl")
#       3 X = df.drop(columns=["completion_time"])
#       4 y = df["completion_time"]
#
# File ~/Desktop/ML_Task_Organizer/venv/lib/python3.13/site-packages/joblib/numpy_pickle.py:749, in load(filename, mmap_mode, ensure_native_byte_order)
#     744                 return load_compatibility(fobj)
#     746             # A memory-mapped array has to be mapped with the endianness
#     747             # it has been written with. Other arrays are coerced to the
#     748             # native endianness of the host system.
# --> 749             obj = _unpickle(
#     750                 fobj,
#     751                 ensure_native_byte_order=ensure_native_byte_order,
#     752                 filename=filename,
# ...
